# %%
import sys

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import feather
from mcs_kfold import MCSKFold
from sklearn.model_selection import GroupKFold, StratifiedKFold
from sklearn.metrics import mean_squared_error
import lightgbm as lgb

sys.path.append("../")
from utils import get_logger, log_evaluation, top2accuracy, eval_func, load_datasets, track_experiment

# %%
def load_datasets(feats, debug=False, n=1000):
    if debug:
        train_feats = [feather.read_dataframe(f'../data/features/{feat}_train.feather').head(n) for feat in feats]
        test_feats = [feather.read_dataframe(f'../data/features/{feat}_test.feather').head(n) for feat in feats]
    else:
        train_feats = [feather.read_dataframe(f'../data/features/{feat}_train.feather') for feat in feats]
        test_feats = [feather.read_dataframe(f'../data/features/{feat}_test.feather') for feat in feats]

    train = pd.concat(train_feats, axis=1)
    test = pd.concat(test_feats, axis=1)
    return train, test

# %%
class Experiment:
    def __init__(self):
        # year使ってる特徴は除く
        self.features = [
            "Base_6",
            "BertPCA50",
            "Momentum",
            "Interaction",
            # "SimultaneousPlatformCount",
            "PublisherPCA",
            "DeveloperPCA",
            "Series",
            "NumSeries",
            "NumSeriesNormalized",
            # "SeriesLifespan"
        ]
        self.cv = "stratified"
        self.params = {
            "objective": "root_mean_squared_error",
            "metric": "root_mean_squared_error",
            "learning_rate": 0.01,
            "num_leaves": 22,
            "min_data_in_leaf": 100,
            "max_depth": 5,
            "subsample_freq": 1,
            "subsample": 0.7,
            "reg_alpha": 0.0001,
            "reg_lambda": 0.0001,
            "colsample_bytree": 0.3,
            "early_stopping_rounds": 100,
            "n_estimators": 20000,
            "seed": 42
        }
        # self.exp_id = exp_id
        # self.logger = get_logger(exp_id)
        # self.model_type = model_type

    def load_data(self):
        train = pd.read_csv("../data/raw/train_fixed.csv")
        test = pd.read_csv("../data/raw/test_fixed.csv")
        whole_df = pd.concat([train, test], ignore_index=True)
        train_idx = ~whole_df["Year_of_Release"].isnull()
        test_idx = whole_df["Year_of_Release"].isnull()

        X_train, X_test = load_datasets(self.features)
        X = pd.concat([X_train, X_test], ignore_index=True)

        del_cols = [col for col in X if "Year_of_Release" in col]
        # target情報が入ってるやつ除く
        X.drop(del_cols, axis=1, inplace=True)

        y = whole_df["Year_of_Release"].to_frame()
        # groups = train["Publisher"].to_frame()
        X_train, X_test = X.loc[train_idx], X.loc[test_idx]
        y_train = y.loc[train_idx]
        return X_train, X_test, y_train

    def fit_and_predict(self, X_train, X_test, y_train):
        if self.cv == "mcs":
            folds = MCSKFold(n_splits=5, shuffle_mc=True, max_iter=100)
        elif self.cv == "group":
            folds = GroupKFold(n_splits=10)
        elif self.cv == "stratified":
            folds = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
            y_to_stratify = y_train["Year_of_Release"]

        oof = np.zeros(len(X_train))
        predictions = np.zeros(len(X_test))
        feature_importance_df = pd.DataFrame()
        fold_scores = []

        # for fold, (train_idx, val_idx) in enumerate(folds.split(X_train, groups=groups)):
        for fold, (train_idx, val_idx) in enumerate(folds.split(X_train, y_to_stratify)):
            print("-" * 100)
            print(f"Fold {fold+1}")
            train_data = lgb.Dataset(X_train.iloc[train_idx], label=y_train.iloc[train_idx])
            val_data = lgb.Dataset(X_train.iloc[val_idx], label=y_train.iloc[val_idx])
            # callbacks = [log_evaluation(self.logger, period=100)]
            clf = lgb.train(self.params, train_data, valid_sets=[train_data, val_data], verbose_eval=1000, early_stopping_rounds=100)  #, feval=eval_func)
            oof[val_idx] = clf.predict(X_train.iloc[val_idx].values, num_iteration=clf.best_iteration)
            fold_score = mean_squared_error(y_train.iloc[val_idx].values, oof[val_idx]) ** .5
            fold_scores.append(fold_score)

            fold_importance_df = pd.DataFrame()
            fold_importance_df["feature"] = X_train.columns.values
            fold_importance_df["importance"] = clf.feature_importance(importance_type="gain")
            fold_importance_df["fold"] = fold + 1
            feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)

            predictions += clf.predict(X_test, num_iteration=clf.best_iteration) / folds.n_splits

        feature_importance_df = feature_importance_df[["feature", "importance"]].groupby("feature").mean().sort_values(by="importance", ascending=False).head(50)
        print("##### feature importance #####")
        print(feature_importance_df)
        cv_score_fold_mean = sum(fold_scores) / len(fold_scores)
        print(f"cv_score_fold_mean: {cv_score_fold_mean}")
        return oof, predictions, cv_score_fold_mean

    def save(self, predictions):
        spsbm = pd.read_csv("./data/raw/atmaCup8_sample-submission.csv")
        spsbm["Global_Sales"] = predictions
        spsbm.to_csv(f"./submissions/{self.exp_id}_sub.csv", index=False)

    def track(self, cv_score):
        # track_experiment(self.exp_id, "model", self.model_type)
        # track_experiment(self.exp_id, "features", self.features)
        # track_experiment(self.exp_id, "cv", self.cv)
        # track_experiment(self.exp_id, "params", self.params)
        track_experiment(self.exp_id, "cv_score", cv_score)

    def run(self):
        X_train, X_test, y_train = self.load_data()
        oof, predictions, cv_score = self.fit_and_predict(X_train, X_test, y_train)
        # predictions = self.correct_predictions(predictions)
        # self.save(predictions)
        # self.track(cv_score)
        return oof, predictions, cv_score

# %%
oof, predictions, cv_score = Experiment().run()
# Out:
# ----------------------------------------------------------------------------------------------------
# Fold 1
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's rmse: 2.3783	valid_1's rmse: 2.50614
# [2000]	training's rmse: 2.04113	valid_1's rmse: 2.28476
# [3000]	training's rmse: 1.83944	valid_1's rmse: 2.18879
# [4000]	training's rmse: 1.68824	valid_1's rmse: 2.13422
# [5000]	training's rmse: 1.562	valid_1's rmse: 2.0944
# [6000]	training's rmse: 1.4525	valid_1's rmse: 2.06687
# [7000]	training's rmse: 1.35703	valid_1's rmse: 2.04533
# [8000]	training's rmse: 1.27175	valid_1's rmse: 2.03076
# [9000]	training's rmse: 1.19604	valid_1's rmse: 2.01921
# [10000]	training's rmse: 1.12689	valid_1's rmse: 2.00963
# [11000]	training's rmse: 1.06453	valid_1's rmse: 2.00052
# Early stopping, best iteration is:
# [11572]	training's rmse: 1.0308	valid_1's rmse: 1.99712
# ----------------------------------------------------------------------------------------------------
# Fold 2
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's rmse: 2.38869	valid_1's rmse: 2.58234
# [2000]	training's rmse: 2.06897	valid_1's rmse: 2.4092
# [3000]	training's rmse: 1.86387	valid_1's rmse: 2.32194
# [4000]	training's rmse: 1.71059	valid_1's rmse: 2.27873
# [5000]	training's rmse: 1.58107	valid_1's rmse: 2.2413
# [6000]	training's rmse: 1.4688	valid_1's rmse: 2.21399
# [7000]	training's rmse: 1.37222	valid_1's rmse: 2.19561
# [8000]	training's rmse: 1.28405	valid_1's rmse: 2.1823
# Early stopping, best iteration is:
# [8704]	training's rmse: 1.22836	valid_1's rmse: 2.17327
# ----------------------------------------------------------------------------------------------------
# Fold 3
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's rmse: 2.38884	valid_1's rmse: 2.40777
# [2000]	training's rmse: 2.05568	valid_1's rmse: 2.19436
# [3000]	training's rmse: 1.85526	valid_1's rmse: 2.10045
# [4000]	training's rmse: 1.70057	valid_1's rmse: 2.04774
# [5000]	training's rmse: 1.57375	valid_1's rmse: 2.01802
# [6000]	training's rmse: 1.46635	valid_1's rmse: 1.99534
# [7000]	training's rmse: 1.37037	valid_1's rmse: 1.97755
# [8000]	training's rmse: 1.28457	valid_1's rmse: 1.96224
# [9000]	training's rmse: 1.20695	valid_1's rmse: 1.9522
# Early stopping, best iteration is:
# [9057]	training's rmse: 1.20317	valid_1's rmse: 1.95149
# ----------------------------------------------------------------------------------------------------
# Fold 4
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's rmse: 2.36734	valid_1's rmse: 2.52653
# [2000]	training's rmse: 2.04115	valid_1's rmse: 2.31247
# [3000]	training's rmse: 1.84149	valid_1's rmse: 2.21342
# [4000]	training's rmse: 1.68986	valid_1's rmse: 2.15563
# [5000]	training's rmse: 1.56691	valid_1's rmse: 2.11945
# [6000]	training's rmse: 1.45756	valid_1's rmse: 2.09133
# [7000]	training's rmse: 1.3617	valid_1's rmse: 2.0674
# [8000]	training's rmse: 1.2772	valid_1's rmse: 2.04825
# [9000]	training's rmse: 1.20233	valid_1's rmse: 2.03183
# [10000]	training's rmse: 1.13341	valid_1's rmse: 2.02029
# [11000]	training's rmse: 1.07082	valid_1's rmse: 2.01164
# [12000]	training's rmse: 1.01373	valid_1's rmse: 2.00321
# [13000]	training's rmse: 0.962498	valid_1's rmse: 1.99576
# [14000]	training's rmse: 0.915418	valid_1's rmse: 1.98919
# Early stopping, best iteration is:
# [14866]	training's rmse: 0.877909	valid_1's rmse: 1.98445
# ----------------------------------------------------------------------------------------------------
# Fold 5
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's rmse: 2.38903	valid_1's rmse: 2.64599
# [2000]	training's rmse: 2.06393	valid_1's rmse: 2.4664
# [3000]	training's rmse: 1.8548	valid_1's rmse: 2.38701
# [4000]	training's rmse: 1.69896	valid_1's rmse: 2.33933
# [5000]	training's rmse: 1.56998	valid_1's rmse: 2.30871
# [6000]	training's rmse: 1.45989	valid_1's rmse: 2.28583
# [7000]	training's rmse: 1.36064	valid_1's rmse: 2.26531
# [8000]	training's rmse: 1.27508	valid_1's rmse: 2.25188
# [9000]	training's rmse: 1.19775	valid_1's rmse: 2.2406
# [10000]	training's rmse: 1.13035	valid_1's rmse: 2.23216
# Early stopping, best iteration is:
# [10749]	training's rmse: 1.08359	valid_1's rmse: 2.22644
# ----------------------------------------------------------------------------------------------------
# Fold 6
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's rmse: 2.38076	valid_1's rmse: 2.53929
# [2000]	training's rmse: 2.04506	valid_1's rmse: 2.31456
# [3000]	training's rmse: 1.84369	valid_1's rmse: 2.21134
# [4000]	training's rmse: 1.68886	valid_1's rmse: 2.15528
# [5000]	training's rmse: 1.56376	valid_1's rmse: 2.1151
# [6000]	training's rmse: 1.45508	valid_1's rmse: 2.08462
# [7000]	training's rmse: 1.36003	valid_1's rmse: 2.06308
# [8000]	training's rmse: 1.27604	valid_1's rmse: 2.04654
# [9000]	training's rmse: 1.20013	valid_1's rmse: 2.03351
# [10000]	training's rmse: 1.13237	valid_1's rmse: 2.02212
# [11000]	training's rmse: 1.07027	valid_1's rmse: 2.01374
# [12000]	training's rmse: 1.0127	valid_1's rmse: 2.00656
# [13000]	training's rmse: 0.960507	valid_1's rmse: 1.99927
# [14000]	training's rmse: 0.91278	valid_1's rmse: 1.993
# Early stopping, best iteration is:
# [14088]	training's rmse: 0.908774	valid_1's rmse: 1.99246
# ----------------------------------------------------------------------------------------------------
# Fold 7
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's rmse: 2.37235	valid_1's rmse: 2.55422
# [2000]	training's rmse: 2.04594	valid_1's rmse: 2.35329
# [3000]	training's rmse: 1.84066	valid_1's rmse: 2.24856
# [4000]	training's rmse: 1.68803	valid_1's rmse: 2.18892
# [5000]	training's rmse: 1.56044	valid_1's rmse: 2.14721
# [6000]	training's rmse: 1.4518	valid_1's rmse: 2.11397
# [7000]	training's rmse: 1.35911	valid_1's rmse: 2.09535
# [8000]	training's rmse: 1.27471	valid_1's rmse: 2.08171
# [9000]	training's rmse: 1.19832	valid_1's rmse: 2.06578
# Early stopping, best iteration is:
# [9238]	training's rmse: 1.18105	valid_1's rmse: 2.06291
# ----------------------------------------------------------------------------------------------------
# Fold 8
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's rmse: 2.39043	valid_1's rmse: 2.52875
# [2000]	training's rmse: 2.06633	valid_1's rmse: 2.35761
# [3000]	training's rmse: 1.86052	valid_1's rmse: 2.27123
# [4000]	training's rmse: 1.70258	valid_1's rmse: 2.21981
# [5000]	training's rmse: 1.57728	valid_1's rmse: 2.18539
# [6000]	training's rmse: 1.46519	valid_1's rmse: 2.15611
# [7000]	training's rmse: 1.37108	valid_1's rmse: 2.13658
# [8000]	training's rmse: 1.28653	valid_1's rmse: 2.12154
# [9000]	training's rmse: 1.21037	valid_1's rmse: 2.10845
# [10000]	training's rmse: 1.14134	valid_1's rmse: 2.09783
# [11000]	training's rmse: 1.08011	valid_1's rmse: 2.09004
# [12000]	training's rmse: 1.02418	valid_1's rmse: 2.08127
# Early stopping, best iteration is:
# [12511]	training's rmse: 0.998093	valid_1's rmse: 2.07724
# ----------------------------------------------------------------------------------------------------
# Fold 9
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's rmse: 2.40088	valid_1's rmse: 2.49321
# [2000]	training's rmse: 2.08179	valid_1's rmse: 2.29962
# [3000]	training's rmse: 1.87579	valid_1's rmse: 2.20116
# [4000]	training's rmse: 1.71671	valid_1's rmse: 2.13938
# [5000]	training's rmse: 1.58517	valid_1's rmse: 2.09271
# [6000]	training's rmse: 1.47393	valid_1's rmse: 2.05885
# [7000]	training's rmse: 1.37452	valid_1's rmse: 2.02971
# [8000]	training's rmse: 1.28788	valid_1's rmse: 2.00823
# [9000]	training's rmse: 1.21148	valid_1's rmse: 1.99079
# [10000]	training's rmse: 1.14145	valid_1's rmse: 1.9758
# [11000]	training's rmse: 1.07964	valid_1's rmse: 1.96329
# [12000]	training's rmse: 1.02262	valid_1's rmse: 1.95395
# [13000]	training's rmse: 0.971074	valid_1's rmse: 1.94749
# [14000]	training's rmse: 0.923644	valid_1's rmse: 1.94033
# [15000]	training's rmse: 0.879831	valid_1's rmse: 1.93506
# Early stopping, best iteration is:
# [15289]	training's rmse: 0.867697	valid_1's rmse: 1.933
# ----------------------------------------------------------------------------------------------------
# Fold 10
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's rmse: 2.37961	valid_1's rmse: 2.48606
# [2000]	training's rmse: 2.0445	valid_1's rmse: 2.28916
# [3000]	training's rmse: 1.84254	valid_1's rmse: 2.19482
# [4000]	training's rmse: 1.69521	valid_1's rmse: 2.14221
# [5000]	training's rmse: 1.5694	valid_1's rmse: 2.10234
# [6000]	training's rmse: 1.46136	valid_1's rmse: 2.07069
# [7000]	training's rmse: 1.36586	valid_1's rmse: 2.04603
# [8000]	training's rmse: 1.28237	valid_1's rmse: 2.03008
# [9000]	training's rmse: 1.20616	valid_1's rmse: 2.01602
# [10000]	training's rmse: 1.13805	valid_1's rmse: 2.00327
# [11000]	training's rmse: 1.07588	valid_1's rmse: 1.99188
# [12000]	training's rmse: 1.01917	valid_1's rmse: 1.98279
# [13000]	training's rmse: 0.967085	valid_1's rmse: 1.97589
# [14000]	training's rmse: 0.91989	valid_1's rmse: 1.96931
# [15000]	training's rmse: 0.877016	valid_1's rmse: 1.96526
# Early stopping, best iteration is:
# [14902]	training's rmse: 0.881098	valid_1's rmse: 1.965
# ##### feature importance #####
#                             importance
# feature
# Platform_PS               1.804788e+06
# Platform_Genre            1.588097e+06
# publisher_Platform_pca_3  1.246008e+06
# developer_Platform_pca_2  6.830716e+05
# Platform_SNES             5.986194e+05
# Platform_3DS              5.420321e+05
# Platform_PS4              5.146959e+05
# Platform_PSV              5.145972e+05
# Platform_PS3              4.223917e+05
# Platform_Rating           3.735135e+05
# name_bert_pca_1           3.656883e+05
# Name                      3.261233e+05
# Platform_XOne             2.797178e+05
# publisher_Platform_pca_0  2.797157e+05
# Platform_PS2              2.549790e+05
# User_Score                2.511779e+05
# publisher_Rating_pca_0    2.275436e+05
# Platform_DS               2.190779e+05
# Platform_SAT              2.052444e+05
# developer_Platform_pca_5  1.944897e+05
# Critic_Count              1.895309e+05
# publisher_Genre_pca_4     1.777437e+05
# User_Count                1.741725e+05
# Platform_XB               1.729297e+05
# publisher_Rating_pca_6    1.504481e+05
# Platform_PSP              1.444177e+05
# Platform_Wii              1.442438e+05
# Platform_X360             1.402516e+05
# Platform_GBA              1.311404e+05
# developer_Platform_pca_4  1.239000e+05
# Platform_N64              1.225281e+05
# developer_Platform_pca_1  1.210945e+05
# Critic_Momentum           1.203957e+05
# Platform_WiiU             1.093563e+05
# publisher_Genre_pca_0     1.018802e+05
# name_bert_pca_12          9.573078e+04
# Critic_Score              9.521049e+04
# Platform_GC               9.190229e+04
# publisher_Genre_pca_3     9.061960e+04
# pub_bert_pca_2            8.857235e+04
# publisher_Rating_pca_1    7.993875e+04
# num_series                7.905360e+04
# developer_Platform_pca_3  7.756635e+04
# dev_bert_pca_33           7.436963e+04
# name_bert_pca_3           7.205164e+04
# publisher_Platform_pca_6  7.160852e+04
# publisher_Rating_pca_3    6.943255e+04
# publisher_Platform_pca_4  6.919454e+04
# User_Momentum             6.851555e+04
# Platform_PC               6.733359e+04
# cv_score_fold_mean: 2.0363385170707513

# %%
oof
# Out:
# array([2010.05376527, 2011.45146244, 2008.37425534, ..., 2011.22987683,
#        2010.72228428, 2008.84634593])

# %%
predictions[:10]
# Out:
# array([2008.03342002, 2008.70685979, 2008.62713822, 1987.88037035,
#        2009.77774943, 2009.50881256, 2010.53197836, 2010.14579503,
#        2009.21320358, 2009.99365054])

# %%
train = pd.read_csv("../data/raw/train_fixed.csv")
test = pd.read_csv("../data/raw/test_fixed.csv")
whole_df = pd.concat([train, test], ignore_index=True)
train_idx = ~whole_df["Year_of_Release"].isnull()
test_idx = whole_df["Year_of_Release"].isnull()

# %%
rounded_pred = np.round(predictions)

# %%
whole_df.loc[test_idx, "Year_of_Release"] = rounded_pred

# %%
train_year_predicted, test_year_predicted = whole_df[:len(train)], whole_df[len(train):]

# %%
train_year_predicted.to_csv(f"../data/raw/train_year_predicted.csv", index=False)
test_year_predicted.to_csv(f"../data/raw/test_year_predicted.csv", index=False)
